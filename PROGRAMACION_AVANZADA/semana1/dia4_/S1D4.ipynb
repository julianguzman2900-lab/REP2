# %% [markdown]
# ## Conceptps claves de HTTP
#
# HTTP (*HyperText Transfer Protocol*)
#
# es un protocolo de **solicitud-respuesta** para comunicación entre **clientes** (navegador, app móvil, script) y **servidores**
#
# ### Forma general de una petición
# ```
# <MÉTODO> <RUTA> HTTP/1.1
# Host: ejemplo.com
# Header-1: valor
# Header-2: valor
# ```
#
# ### Métodos HTTP (CRUD)
# - **GET** = leer recursos (sin cambiar estado).
# - **POST** = crear recursos (cambia estado).
# - **PUT** = **reemplazar** un recurso completo (actualizar).
# - **PATCH** = **modificar parcialmente** un recurso.
# - **DELETE** = borrar un recurso..
#
# ### Idempotencia
# Una operación es **idempotente** si ejecutarla **1 vez** o **N veces** produce el **mismo estado final** del servidor.
# - **Idempotentes:** `GET`, `PUT`, `DELETE`
# - **No idempotente:** `POST` (cada `POST` podría crear un nuevo recurso).
#
# ### Códigos de estado más comunes
# - **200 OK** → todo bien en una lectura/operación.
# - **201 Created** → recurso creado exitosamente (usar en `POST`).
# - **204 No Content** → operación exitosa **sin** cuerpo (frecuente en `DELETE` o `PUT`).
# - **400 Bad Request** → error del cliente (p. ej., JSON mal formado).
# - **401 Unauthorized / 403 Forbidden** → falta autenticación o permisos.
# - **404 Not Found** → recurso o ruta inexistente.
# - **500 Internal Server Error** → error no controlado en el servidor.
#
# ### Headers clave
# - **Content-Type** → formato del cuerpo que **envío** (`application/json`, `application/x-www-form-urlencoded`, `text/html`, etc.).
# - **Accept** → formatos que el cliente **acepta recibir**.
# - **Content-Length** → cantidad de bytes del cuerpo (el servidor/cliente lo usa para leer el cuerpo).
# - **Host**, **User-Agent**, **Authorization**, **Cache-Control**, etc. (otros importantes).
#
#
# ### Cuerpo (body) de la petición
# - **`application/json`** → envío un JSON (texto) en el cuerpo.
# - **`application/x-www-form-urlencoded`** → envío pares `clave=valor&...` como en formularios HTML.
# - (También existen `multipart/form-data` para archivos, `text/plain`, etc.)

# %%
from http.server import BaseHTTPRequestHandler, HTTPServer
import json

class MyHandler(BaseHTTPRequestHandler):
    def send_json(self, data):
        self.send_response(200)
        self.send_header('Content-Type', 'application/json')
        self.end_headers()
        body = json.dumps(data).encode('utf-8')
        self.wfile.write(body)

    def do_GET(self):
        if self.path == '/':
            self.send_json({'message': 'Hola Mundo desde la raiz'})
        elif self.path == '/hello':
            self.send_json({'message': 'Hello World from /hello'})
        else:
            self.send_response(404)
            self.end_headers()
            self.wfile.write(b'Not Found')

if __name__ == '__main__':
    server = HTTPServer(('localhost', 8080), MyHandler)
    print('Servidor HTTP escuchando en http://localhost:8080')
    server.serve_forever()
# Out:
# Servidor HTTP escuchando en http://localhost:8080
# 127.0.0.1 - - [14/May/2026 08:38:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 08:38:15] "GET /apple-touch-icon-precomposed.png HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:38:15] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:38:16] "GET /apple-touch-icon.png HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:38:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 08:38:43] "GET /apple-touch-icon-precomposed.png HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:38:43] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:38:43] "GET /apple-touch-icon.png HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:39:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 08:39:06] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:39:25] "GET /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 08:39:36] "GET /adios HTTP/1.1" 404 -
# 127.0.0.1 - - [14/May/2026 08:39:49] "GET /.well-known/appspecific/com.chrome.devtools.json HTTP/1.1" 404 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      23 server = HTTPServer(('localhost', 8080), MyHandler)
#      24 print('Servidor HTTP escuchando en http://localhost:8080')
# ---> 25 server.serve_forever()
#
# File /usr/local/Cellar/python@3.11/3.11.6/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socketserver.py:233, in BaseServer.serve_forever(self, poll_interval)
#     230 selector.register(self, selectors.EVENT_READ)
#     232 while not self.__shutdown_request:
# --> 233     ready = selector.select(poll_interval)
#     234     # bpo-35017: shutdown() called during select(), exit immediately.
#     235     if self.__shutdown_request:
#
# File /usr/local/Cellar/python@3.11/3.11.6/Frameworks/Python.framework/Versions/3.11/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Express
# - **Express** es un **framework minimalista** para Node.js.
# - Simplifica la creación de servidores HTTP, manejando por nosotros tareas comunes como:
#   - Manejo de rutas (GET, POST, PUT, DELETE).
#   - Lectura de parámetros y JSON en el body.
#   - Middleware para procesar datos antes de llegar a la ruta.
#
# ## qué es Middleware?
# En Express, un **middleware** es una función que se ejecuta **entre** la petición (request) y la respuesta (response).
#
# **capa intermedia que procesa la petición o respuesta.**
#
# ### Estructura de un middleware
# ```js
# function miMiddleware(req, res, next) {
#   console.log("Método:", req.method, "Ruta:", req.url);
#   next(); // pasa al siguiente middleware o a la ruta
# }
#
# app.use(miMiddleware)
# ```
#
#
# - `req`: la petición del cliente.
# - `res`: la respuesta del servidor.
# - `next()`: función que llama al siguiente middleware en la cadena.
#
# ### Ejemplo de Middleware para procesos JSON

# %%
const express = require('express');
const app = express();
const port = 3000;

app.use(express.json());

app.post("/usuario", (req, res) => {
    console.log(req.body);
    // res.send("Usuario recibido");
    res.json({ mensaje: "Usuario recibido", datos: req.body });
})

app.listen(port, () => { console.log(`Servidor escuchando en http://localhost:${port}`) });
# Out:
#   Cell In[4], line 1
#     const express = require('express');
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Ejemplo 2:
# ```js
# const express = require('express');
# const app = express();
# const port = 3000;
#
# app.use(express.json());
#
# app.post("/usuario", (req, res) => {
#     console.log(req.body);
#     // res.send("Usuario recibido");
#     res.json({ mensaje: "Usuario recibido", datos: req.body });
# })
#
# app.post("/registro", (req, res) => {
#     const { nombre, email, password } = req.body;
#     console.log(`Nombre: ${nombre}, Email: ${email}, Password: ${password}`);
#     res.json({ mensaje: "Registro exitoso", datos: req.body });
# });
#
# app.listen(port, () => { console.log(`Servidor escuchando en http://localhost:${port}`) });
#
#
# ```
#
# ## Ejercicio práctico
# Crea un servidor Express con una ruta `POST /login` que reciba JSON con `usuario` y `password`.
#
#
# - Si `usuario === "admin"` y `password === "1234"`, responder:
#   ```json
#   { "status": "ok", "mensaje": "Login exitoso" }
#   ```
#
# - Si no, responder:
#   ```json
#   { "status": "error", "mensaje": "Credenciales inválidas" }
#   ```

# %% [markdown]
# ## Pasos iniciales al comenzar un nuevo proyecto
# ```bash
# mkdir nombre_proyecto
# cd nombre_proyecto
# npm init -y
# npm install express
# npm install nodemon
# ```
# modificar el `package.json` para crear el comando rápido de inicio `dev: "nodemon nombre_archivo.js" `

# %% [markdown]
# ## `__dirname`, `path` y middleware en Express
#
# ### ¿Qué es `__dirname`?
# En Node.js, la variable especial `__dirname` siempre contiene la **ruta absoluta de la carpeta en la que se encuentra el archivo actual**.
#
# Ejemplo:
# Si tienes el archivo `servidor.js` en la carpeta:
# ```
# C:\proyectos\mi-servidor-express\servidor.js
# ```
#
# El valor de `__dirname` dentro de `servidor.js` será:
# ```
# C:\proyectos\mi-servidor-express
# ```
#
# ###  ¿Qué es el módulo `path`?
# El módulo **`path`** es un módulo interno de Node.js que permite trabajar con rutas de archivos y carpetas de manera **segura y multiplataforma**.
#
#
# Por ejemplo:
# ```js
# const path = require("path");
#
# // Une __dirname con "public/index.html"
# const ruta = path.join(__dirname, "public", "index.html");
#
# console.log(ruta);
# ```
#
#
# En Windows imprimirá algo como:
# ```
# C:\proyectos\mi-servidor-express\public\index.html
# ```
#
# En Linux/Mac imprimirá:
# ```
# /home/usuario/mi-servidor-express/public/index.html
# ```
#
#
# ###  Middleware de archivos estáticos
# La línea:
# ```js
# app.use(express.static(path.join(__dirname, "public")));
# ```
# hace que Express busque automáticamente los archivos en la carpeta **`public`** y los sirva directamente al navegador.

# %% [markdown]
# Ejemplo:
# - Si existe `public/index.html`, se puede abrir en el navegador con:
#   ```http://localhost:3000/index.html```
#
# - Si existe `public/img/logo.png`, se abre con:
#   ```http://localhost:3000/img/logo.png```
#
#
# ## Resumen
# - `__dirname` → Ruta absoluta de la carpeta donde está el archivo actual.
# - `path` → Módulo de Node.js para unir y manipular rutas de forma segura.
# - Middleware en Express → Funciones intermedias que procesan las peticiones en orden.
# - `express.static` → Middleware que automáticamente sirve archivos de la carpeta indicada.
